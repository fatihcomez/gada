# %% [markdown]
# # **Capstone project: Providing data-driven suggestions for HR**

# %% [markdown]
# ## Description and deliverables
#
# This capstone project is an opportunity to analyze a dataset and build predictive models that can provide insights to the Human Resources (HR) department of a large consulting firm.
#
# There will be two outcomes: One is a brief one-page summary of this project to present to external stakeholders as the data professional in Salifort Motors. The other is a complete code notebook.
#
# We will either use a regression model or machine learning model to predict whether or not an employee will leave the company.
#
# In the deliverable, the model evaluation (and interpretation if applicable), a data visualization(s) of our choice that is directly related to the question we ask, ethical considerations, and the resources we used to troubleshoot and find answers or solutions will be included.

# %% [markdown]
# # **PACE stages**

# %% [markdown]
# ![Screenshot 2022-08-04 5.47.37 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## **Pace: Plan**
#
# Questions in the PACE Strategy Document will be considered to reflect on the Plan stage.
#
# In this stage, we will consider the following:

# %% [markdown]
# ### Understand the business scenario and problem
#
# The HR department at Salifort Motors wants to take some initiatives to improve employee satisfaction levels at the company. They collected data from employees, but now they don’t know what to do with it. They refer to the data analytics professional and ask to provide data-driven suggestions based on the understanding of the data. They have the following question: what’s likely to make the employee leave the company?
#
# Our goals in this project are to analyze the data collected by the HR department and to build a model that predicts whether or not an employee will leave the company.
#
# If we can predict employees likely to quit, it might be possible to identify factors that contribute to their leaving. Because it is time-consuming and expensive to find, interview, and hire new employees, increasing employee retention will be beneficial to the company.

# %% [markdown]
# ### Familiarize with the HR dataset
#
# The dataset contains 15,000 rows and 10 columns for the variables listed below.
#
# Variable  |Description |
# -----|-----|
# satisfaction_level|Employee-reported job satisfaction level [0&ndash;1]|
# last_evaluation|Score of employee's last performance review [0&ndash;1]|
# number_project|Number of projects employee contributes to|
# average_monthly_hours|Average number of hours employee worked per month|
# time_spend_company|How long the employee has been with the company (years)
# Work_accident|Whether or not the employee experienced an accident while at work
# left|Whether or not the employee left the company
# promotion_last_5years|Whether or not the employee was promoted in the last 5 years
# Department|The employee's department
# salary|The employee's salary (U.S. dollars)

# %% [markdown]
# ### Reflect on these questions in the plan stage.
#
# -  Who are your stakeholders for this project?
# - What are you trying to solve or accomplish?
# - What are your initial observations when you explore the data?
# - What resources do you find yourself using as you complete this stage? (Make sure to include the links.)
# - Do you have any ethical considerations in this stage?

# %% [markdown]
# [Responses]

# %% [markdown]
# ## Step 1. Imports
#
# *   Import packages
# *   Load dataset

# %% [markdown]
# ### Import packages

# %%
# ===============================
# Importing Required Packages
# ===============================

# --------------------------------------------
# Data Manipulation & Analysis
# --------------------------------------------
# - pandas  → provides powerful data structures like DataFrame and tools for data manipulation and analysis
# - numpy   → supports numerical operations, including array computations and mathematical functions
# --------------------------------------------
import pandas as pd
import numpy as np

# --------------------------------------------
# Data Visualization
# --------------------------------------------
# - matplotlib.pyplot  → core plotting library for creating static visualizations (e.g., line, bar, hist, scatter)
# - scatter_matrix     → a function from pandas.plotting that plots pairwise scatter plots to visualize correlations
# - seaborn            → built on top of matplotlib; provides a high-level interface for attractive and informative statistical graphics
# --------------------------------------------
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import seaborn as sns 


from scipy.stats import zscore

# %%
# Load dataset into a dataframe
df0 = pd.read_csv("../data/HR_comma_sep.csv")

# Display first few rows of the dataframe
df0.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %% [markdown]
# ## Step 2. Data Exploration (Initial EDA and data cleaning)
#
# - Understand the variables
# - Clean the dataset (missing data, redundant data, outliers)

# %% [markdown]
# ### Gather basic information about the data

# %%
# Gather basic information about the data
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# The "left" column and "promotion_last_5years" column should be categorical, but they are currently numerical.

# %%
# Get more details about object features: "Department"
df0["Department"].value_counts()
# Out:
# Department
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: count, dtype: int64

# %%
# Get more details about object features: "salary"
df0["salary"].value_counts()
# Out:
# salary
# low       7316
# medium    6446
# high      1237
# Name: count, dtype: int64

# %% [markdown]
# ### Gather descriptive statistics about the data

# %%
# Gather descriptive statistics about the data
df0.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
# Visualize to get more familiar with data
df0.hist(bins = 50, figsize = (20, 15))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Rename columns

# %% [markdown]
# As a data cleaning step, rename the columns as needed. Standardize the column names so that they are all in `snake_case`, correct any column names that are misspelled, and make column names more concise as needed.

# %%
# Display all column names
df0.columns.tolist()
# Out:
# ['satisfaction_level',
#  'last_evaluation',
#  'number_project',
#  'average_montly_hours',
#  'time_spend_company',
#  'Work_accident',
#  'left',
#  'promotion_last_5years',
#  'Department',
#  'salary']

# %%
# Rename columns as needed
df0.columns = df0.columns.str.lower()

# Display all column names after the update
df0.columns.tolist()
# Out:
# ['satisfaction_level',
#  'last_evaluation',
#  'number_project',
#  'average_montly_hours',
#  'time_spend_company',
#  'work_accident',
#  'left',
#  'promotion_last_5years',
#  'department',
#  'salary']

# %% [markdown]
# ### Check missing values

# %% [markdown]
# Check for any missing values in the data.

# %%
# Check for missing values
df0.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# work_accident            0
# left                     0
# promotion_last_5years    0
# department               0
# salary                   0
# dtype: int64

# %% [markdown]
# ### Check duplicates

# %% [markdown]
# Check for any duplicate entries in the data.

# %%
# Check for duplicates
df0.duplicated().sum()
# Out:
# np.int64(3008)

# %%
# Inspect some rows containing duplicates as needed
df0_dups = df0[df0.duplicated()]
df0_dups
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 396                  0.46             0.57               2
# 866                  0.41             0.46               2
# 1317                 0.37             0.51               2
# 1368                 0.41             0.52               2
# 1461                 0.42             0.53               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  work_accident  left  \
# 396                     139                   3              0     1
# 866                     128                   3              0     1
# ...

# %%
# Drop duplicates and save resulting dataframe in a new variable as needed
df1 = df0.drop_duplicates()

# Display first few rows of new dataframe as needed
df1.head(10)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
# 5                0.41             0.50               2                   153
# 6                0.10             0.77               6                   247
# 7                0.92             0.85               5                   259
# 8                0.89             1.00               5                   224
# 9                0.42             0.53               2                   142
#
#    time_spend_company  work_accident  left  promotion_last_5years department  \
# ...

# %% [markdown]
# ### Check outliers

# %% [markdown]
# Check for outliers in the data.

# %%
sns.boxplot(data=df1, x="time_spend_company")  
plt.title("Tenure")
plt.show()

# %%
# Determine the number of rows containing outliers

# Focus on numerical columns
numeric_cols = df1.select_dtypes(include = "number").columns

# Mark the outlier rows
outlier_mask = pd.DataFrame(False, index = df1.index, columns = numeric_cols)

# Create the function to calculate IQR and then identify the 
for col in numeric_cols:
    Q1 = df1[col].quantile(0.25)
    Q3 = df1[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outlier_mask[col] = (df1[col] < lower_bound) | (df1[col] > upper_bound)

# Output the count of rows with the outliers
outlier_row_count = outlier_mask.any(axis=1).sum()
print(f"Rows with outliers: {outlier_row_count}")
# Out:
# Rows with outliers: 4425

# %%
# Alternatively calculate using z-score
# Focus on numerical columns
numeric_df = df1.select_dtypes(include="number")

# Calculate Z-score
z_scores = np.abs(zscore(numeric_df))

# If a row has a z-score greater than 3 in at least one column, consider to contain an outlier.
outlier_row_count = (z_scores > 3).any(axis=1).sum()
print(f"Rows with outliers: {outlier_row_count}")
# Out:
# Rows with outliers: 378

# %% [markdown]
# Certain types of models are more sensitive to outliers than others. Consider whether to remove outliers, based on the type of model decided to use.

# %% [markdown]
# # pAce: Analyze Stage
# - Perform EDA (analyze relationships between variables)

# %% [markdown]
# ### Reflect on these questions in the analyze stage.
#
# - What did you observe about the relationships between variables?
# - What do you observe about the distributions in the data?
# - What transformations did you make with your data? Why did you chose to make those decisions?
# - What are some purposes of EDA before constructing a predictive model?
# - What resources do you find yourself using as you complete this stage? (Make sure to include the links.)
# - Do you have any ethical considerations in this stage?

# %% [markdown]
# [Responses]

# %% [markdown]
# ## Step 2. Data Exploration (Continue EDA)
#
# Begin by understanding how many employees left and what percentage of all employees this figure represents.

# %%
# Get numbers of people who left vs. stayed
df1["left"].value_counts()
# Out:
# left
# 0    10000
# 1     1991
# Name: count, dtype: int64

# %%
# Get percentages of people who left vs. stayed
left = df1["left"] == 1
stayed = df1["left"] == 0
total = left.sum() + stayed.sum()
percantage_left = left.sum() / total.sum()

print(f"Percantage of employees which left the company: {percantage_left: .2%}")
# Out:
# Percantage of employees which left the company:  16.60%

# %% [markdown]
# ### Data visualizations

# %% [markdown]
# Now, examine variables that we're interested in, and create plots to visualize relationships between variables in the data.

# %%
# Create a plot as needed

# %%
# Create a plot as needed

# %%
# Create a plot as needed

# %%
# Create a plot as needed

# %%
# Create a plot as needed

# %%
# Create a plot as needed

# %%
# Create a plot as needed

# %%
# Create a plot as needed

# %% [markdown]
# ### Insights

# %% [markdown]
# [Insights that can be gathered from the plots created to visualize the data]

# %% [markdown]
# [Responses]

# %% [markdown]
# # paCe: Construct Stage
# - Determine which models are most appropriate
# - Construct the model
# - Confirm model assumptions
# - Evaluate model results to determine how well your model fits the data

# %% [markdown]
# ## Recall model assumptions
#
# **Logistic Regression model assumptions**
# - Outcome variable is categorical
# - Observations are independent of each other
# - No severe multicollinearity among X variables
# - No extreme outliers
# - Linear relationship between each X variable and the logit of the outcome variable
# - Sufficiently large sample size

# %% [markdown]
# ### Reflect on these questions in the constructing stage.
#
# - Do we notice anything odd?
# - Which independent variables were choosen for the model and why?
# - Are each of the assumptions met?
# - How well does the model fit the data?
# - Can it be improved? Is there anything to change about the model?
# - What resources do we find ourselves using as we complete this stage? (Make sure to include the links.)
# - Do we have any ethical considerations in this stage?

# %% [markdown]
# [Responses]

# %% [markdown]
# ## Step 3. Model Building, Step 4. Results and Evaluation
# - Fit a model that predicts the outcome variable using two or more independent variables
# - Check model assumptions
# - Evaluate the model

# %% [markdown]
# ### Identify the type of prediction task.

# %% [markdown]
# [Responses]

# %% [markdown]
# ### Identify the types of models most appropriate for this task.

# %% [markdown]
# [Responses]

# %% [markdown]
# ### Modeling
#
# Add as many cells as we need to conduct the modeling process.

# %% [markdown]
# # pacE: Execute Stage
# - Interpret model performance and results
# - Share actionable steps with stakeholders

# %% [markdown]
# ## Recall evaluation metrics
#
# - **AUC** is the area under the ROC curve; it's also considered the probability that the model ranks a random positive example more highly than a random negative example.
# - **Precision** measures the proportion of data points predicted as True that are actually True, in other words, the proportion of positive predictions that are true positives.
# - **Recall** measures the proportion of data points that are predicted as True, out of all the data points that are actually True. In other words, it measures the proportion of positives that are correctly classified.
# - **Accuracy** measures the proportion of data points that are correctly classified.
# - **F1-score** is an aggregation of precision and recall.

# %% [markdown]
# ### Reflect on these questions in the executing stage.
#
# - What key insights emerged from the model(s)?
# - What business recommendations do we propose based on the models built?
# - What potential recommendations would we make to the manager/company?
# - Do we think your model could be improved? Why or why not? How?
# - Given what we know about the data and the models we were using, what other questions could we address for the team?
# - What resources do we find ourselves using as you complete this stage? (Make sure to include the links.)
# - Do we have any ethical considerations in this stage?

# %% [markdown]
# [Responses]

# %% [markdown]
# ## Step 4. Results and Evaluation
# - Interpret model
# - Evaluate model performance using metrics
# - Prepare results, visualizations, and actionable steps to share with stakeholders

# %% [markdown]
# ### Summary of model results
#
# [Summary here]

# %% [markdown]
# ### Conclusion, Recommendations, Next Steps
#
# [Conclusion, recommendations, and next steps]
